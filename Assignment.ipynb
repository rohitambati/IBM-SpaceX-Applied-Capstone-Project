# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Rohit Ambati**
#
# Graduate Student pursuing Master's in Data Science

# %% [markdown]
# *During my undergrad, I attended a tech career conference conducted at BITS Pilani where industry experts, CEO's of start-up and MNC's shared their experiences with their respective feilds. One thing that all of them mentioned in their presentations and had in common was, how data had been driving their businesses and the role they played in providing service to their customers. The requirments for data analysts, data scientists and data engineers was soo high to put this exponential increase of data to a better use. This intrigue motivated me to pursue my career in the field of data science.*

# %% [markdown]
# ### The below cell contains a function that returns the sum of two integers

# %%
def sum(a,b):
    return a+b
sum(1,2)
# Out:
# 3

# %% [markdown]
# This is a numbered list:
#
# 1. First list item
# 2. Second list item
# 3. Third list item
#
# This is a bulleted list:
#
# - Unordered item
# - Unordered item
# - Unordered item
#
# The link takes you to the IBM's Official Web Page :
# [IBM](https://www.ibm.com/us-en/)
#
# This is a sample table :
#
# | Name | Age |
# | ---- | --- |
# | John | 10  |
# | Alex | 20  |
#
#
# ~~This is a striked text~~
